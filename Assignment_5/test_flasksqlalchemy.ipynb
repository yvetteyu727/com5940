# %%
import pymysql
pymysql.install_as_MySQLdb()

# %%
from product_model import *

# %%
result = db.engine.execute('select * from chuan')
for i in result:
    print(i)
result = db.engine.execute('select * from chuan')
final_result = [list(i) for i in result]
dataset = []
dict = {}
for i in final_result:
    dict['ID'] = i[0]
    dict['dish_name'] = i[1]
    dict['Chinese_Name'] = i[2]
    dict['Pronunciation'] = i[3]
    dict['image_url'] = i[4]
    dataset.append(dict.copy())
print(dataset)
# Out:
# (1, 'Hot & Spicy Chicken', '重慶辣子雞', 'chóng qìng là zǐ jī', 'https://dl.airtable.com/.attachments/bb95988c31ce10d1166f152914b75b58/a7cb706e/d20eb9fa23527d6dbd0953118b7980b7f4282abf148733-6qKOTw_fw658')
# (2, 'Dandan noodles', '擔擔麵', 'dān dān miàn ', 'https://dl.airtable.com/.attachments/e4e682d8783c0248f2c96f7e57c614c6/f1ab71fc/535db1ee324bca8a67000d807b914e71acea31807e67b-tQwkg2_fw658')
# (3, 'Fuqi feipian', '夫妻肺片', 'fū qī fèi piàn', 'https://dl.airtable.com/.attachments/f1024a41da9c3283be28474c38ebfded/5f82d76e/0ddaf7f3dc8d785442c976b70298e93c66f49871536b5-Zqia9p_fw658')
# (4, 'Sichuan hotpot\t', '四川火鍋', 'sì chuān huǒ guō', 'https://dl.airtable.com/.attachments/6d10a96bfb8ad7da7d80e9a6af566d36/85076560/91fb4a4b62d9df132a7e6d1d23e113184db9fbf0254944-GvvyAl_fw658')
# (5, 'Mapo tofu', '麻婆豆腐', '\tmá pó dòu fǔ', 'https://dl.airtable.com/.attachments/38bbdcbc3d2ab79c3311fcbbbd3e1e14/b729b2ca/83601b86b4adb937bcfda49ea3509fb604e4928226fcf-0MQkw0_fw658')
# ...

# %%
# Update Example
pid = 1
chuan = Chuan.query.filter_by(ID=pid).first()
chuan.dish_name = "Hot and Spicy chicken"
db.session.commit()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-6-be8acce962fc> in <module>
#       1 # Update Example
#       2 pid = 1
# ----> 3 chuan = Chuan.query.filter_by(ID=pid).first()
#       4 chuan.dish_name = "Hot and Spicy chicken"
#       5 db.session.commit()
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in first(self)
#    3238             ret = list(self)[0:1]
#    3239         else:
# -> 3240             ret = list(self[0:1])
#    3241         if len(ret) > 0:
#    3242             return ret[0]
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in __getitem__(self, item)
#    3016                 return list(res)[None : None : item.step]
#    3017             else:
# -> 3018                 return list(res)
#    3019         else:
#    3020             if item == -1:
#
# ...

# %%
# Insert Example
chuan = Chuan(ID='10',dish_name='Chop pepper fish head',Chinese_Name='剁椒鱼头',Pronunciation='duo jiao yu tou',image_url='ok')
db.session.add(chuan)
db.session.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# /opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# /opt/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %%
# Delete Example
pid = 10
chuan = Chuan.query.filter_by(ID=pid).first()
db.session.delete(chuan)
db.session.commit()
